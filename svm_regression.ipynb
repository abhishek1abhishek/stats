# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv('/content/house-prices.csv')

# %%
df1
# Out:
#      Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0       1  114300  1790         2          2       2    No         East
# 1       2  114200  2030         4          2       3    No         East
# 2       3  114800  1740         3          2       1    No         East
# 3       4   94700  1980         3          2       3    No         East
# 4       5  119800  2130         3          3       3    No         East
# ..    ...     ...   ...       ...        ...     ...   ...          ...
# 123   124  119700  1900         3          3       3   Yes         East
# 124   125  147900  2160         4          3       3   Yes         East
# 125   126  113500  2070         2          2       2    No        North
# 126   127  149900  2020         3          3       1    No         West
# 127   128  124600  2250         3          3       4    No        North
#
# [128 rows x 8 columns]

# %%
x=df1.drop("Price",axis=1)

# %%
x.head()
# Out:
#    Home  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0     1  1790         2          2       2    No         East
# 1     2  2030         4          2       3    No         East
# 2     3  1740         3          2       1    No         East
# 3     4  1980         3          2       3    No         East
# 4     5  2130         3          3       3    No         East

# %%
y=df1["Price"]

# %%
y.head()
# Out:
# 0    114300
# 1    114200
# 2    114800
# 3     94700
# 4    119800
# Name: Price, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale=StandardScaler()

# %%
x_train_scaled = scale.fit_transform(x_train)
x_test_scaled = scale.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-78b17f4af2e0> in <cell line: 1>()
# ----> 1 x_train_scaled = scale.fit_transform(x_train)
#       2 x_test_scaled = scale.transform(x_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     876         if y is None:
#     877             # fit method of arity 1 (unsupervised transformation)
# --> 878             return self.fit(X, **fit_params).transform(X)
#     879         else:
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df2=df1

# %%
df2
# Out:
#      Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0       1  114300  1790         2          2       2    No         East
# 1       2  114200  2030         4          2       3    No         East
# 2       3  114800  1740         3          2       1    No         East
# 3       4   94700  1980         3          2       3    No         East
# 4       5  119800  2130         3          3       3    No         East
# ..    ...     ...   ...       ...        ...     ...   ...          ...
# 123   124  119700  1900         3          3       3   Yes         East
# 124   125  147900  2160         4          3       3   Yes         East
# 125   126  113500  2070         2          2       2    No        North
# 126   127  149900  2020         3          3       1    No         West
# 127   128  124600  2250         3          3       4    No        North
#
# [128 rows x 8 columns]

# %%
label_encoder = LabelEncoder()
df2['newNeig'] = label_encoder.fit_transform(df2['Neighborhood'])

# %%
df2
# Out:
#      Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood  \
# 0       1  114300  1790         2          2       2    No         East
# 1       2  114200  2030         4          2       3    No         East
# 2       3  114800  1740         3          2       1    No         East
# 3       4   94700  1980         3          2       3    No         East
# 4       5  119800  2130         3          3       3    No         East
# ..    ...     ...   ...       ...        ...     ...   ...          ...
# 123   124  119700  1900         3          3       3   Yes         East
# 124   125  147900  2160         4          3       3   Yes         East
# 125   126  113500  2070         2          2       2    No        North
# 126   127  149900  2020         3          3       1    No         West
# 127   128  124600  2250         3          3       4    No        North
#
#      newNeig
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# ...

# %%
df2['newBrick'] = label_encoder.fit_transform(df2['Brick'])

# %%
df2
# Out:
#      Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood  \
# 0       1  114300  1790         2          2       2    No         East
# 1       2  114200  2030         4          2       3    No         East
# 2       3  114800  1740         3          2       1    No         East
# 3       4   94700  1980         3          2       3    No         East
# 4       5  119800  2130         3          3       3    No         East
# ..    ...     ...   ...       ...        ...     ...   ...          ...
# 123   124  119700  1900         3          3       3   Yes         East
# 124   125  147900  2160         4          3       3   Yes         East
# 125   126  113500  2070         2          2       2    No        North
# 126   127  149900  2020         3          3       1    No         West
# 127   128  124600  2250         3          3       4    No        North
#
#      newNeig  newBrick
# 0          0         0
# 1          0         0
# 2          0         0
# ...

# %%
df2=df2.drop(["Brick","Neighborhood"],axis=1)

# %%
df2
# Out:
#      Home   Price  SqFt  Bedrooms  Bathrooms  Offers  newNeig  newBrick
# 0       1  114300  1790         2          2       2        0         0
# 1       2  114200  2030         4          2       3        0         0
# 2       3  114800  1740         3          2       1        0         0
# 3       4   94700  1980         3          2       3        0         0
# 4       5  119800  2130         3          3       3        0         0
# ..    ...     ...   ...       ...        ...     ...      ...       ...
# 123   124  119700  1900         3          3       3        0         1
# 124   125  147900  2160         4          3       3        0         1
# 125   126  113500  2070         2          2       2        1         0
# 126   127  149900  2020         3          3       1        2         0
# 127   128  124600  2250         3          3       4        1         0
#
# [128 rows x 8 columns]

# %%
x=df2.drop("Price",axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
x_train_scaled = scale.fit_transform(x_train)
x_test_scaled = scale.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[ 1.13399197, -0.42833005,  0.        , -0.92441628,  1.52427396,
#         -1.2405017 , -0.75447384],
#        [ 0.68954555, -0.33566904,  0.        ,  1.08176373, -0.52146214,
#          0.0122822 , -0.75447384],
#        [-0.92157273,  1.14690708,  1.40054934,  1.08176373,  0.50140591,
#          1.26506609,  1.32542701],
#        [-1.14379594, -1.44760113,  0.        , -0.92441628,  0.50140591,
#          0.0122822 , -0.75447384],
#        [-0.22712519, -1.30860962, -1.40054934, -0.92441628, -0.52146214,
#         -1.2405017 ,  1.32542701],
#        [-1.58824236, -0.79897408,  0.        ,  1.08176373,  0.50140591,
#          1.26506609,  1.32542701],
#        [ 1.6062163 , -0.33566904,  0.        ,  1.08176373,  0.50140591,
#         -1.2405017 , -0.75447384],
#        [ 1.27288148,  0.49828003,  0.        , -0.92441628,  0.50140591,
#         -1.2405017 , -0.75447384],
#        [ 0.35621074, -0.33566904,  0.        , -0.92441628, -0.52146214,
# ...

# %%
from sklearn.svm import SVR

# %%
svr_model = SVR(kernel='linear')

# %%
svr_model.fit(x_train_scaled, y_train)
# Out:
# SVR(kernel='linear')

# %%
pred = svr_model.predict(x_test_scaled)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test, pred)
r2 = r2_score(y_test, pred)

# %%
mse
# Out:
# 507727145.8713131

# %%
r2
# Out:
# -0.010499466061891338

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
sns.pairplot(df1)

# %%
svr_model1 = SVR(kernel='poly', degree=3)

# %%
svr_model1.fit(x_train_scaled, y_train)
# Out:
# SVR(kernel='poly')

# %%
pred1 = svr_model1.predict(x_test_scaled)

# %%
mse = mean_squared_error(y_test, pred1)
r2 = r2_score(y_test, pred1)

# %%
r2
# Out:
# -0.021169652338050238

# %%
mse
# Out:
# 513088398.8020273
