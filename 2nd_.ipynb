# %%
import numpy as np
import pandas as pd

# %%
students= { 'name':['ramu','aakash','raman','raju'],
          'age':['18','21','20','20'] ,
           'marks':['90','65','72','88']}

# %%
df1=pd.DataFrame(students)

# %%
df1
# Out:
#      name age marks
# 0    ramu  18    90
# 1  aakash  21    65
# 2   raman  20    72
# 3    raju  20    88

# %%
df1.marks
# Out:
# 0    90
# 1    65
# 2    72
# 3    88
# Name: marks, dtype: object

# %%
df1.marks.max()
# Out:
# '90'

# %%
df1.set_index('name')
# Out:
#        age marks
# name
# ramu    18    90
# aakash  21    65
# raman   20    72
# raju    20    88

# %%
df1
# Out:
#      name age marks
# 0    ramu  18    90
# 1  aakash  21    65
# 2   raman  20    72
# 3    raju  20    88

# %%
df1=df1.set_index('name')

# %%
df1
# Out:
#        age marks
# name
# ramu    18    90
# aakash  21    65
# raman   20    72
# raju    20    88

# %%
df1.reset_index()
# Out:
#      name age marks
# 0    ramu  18    90
# 1  aakash  21    65
# 2   raman  20    72
# 3    raju  20    88

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
#      name age marks
# 0    ramu  18    90
# 1  aakash  21    65
# 2   raman  20    72
# 3    raju  20    88

# %%
df1.set_index('name',inplace=True)

# %%
df1
# Out:
#        age marks
# name
# ramu    18    90
# aakash  21    65
# raman   20    72
# raju    20    88

# %%
df1['age']
# Out:
# name
# ramu      18
# aakash    21
# raman     20
# raju      20
# Name: age, dtype: object

# %%
#now name is not a column name

# %%
df1.reset_index(inplace=True)

# %%
df1['Name']=['raju','aakash','raman','piyush']

# %%
df1
# Out:
#      name age marks    Name
# 0    ramu  18    90    raju
# 1  aakash  21    65  aakash
# 2   raman  20    72   raman
# 3    raju  20    88  piyush

# %%
df1.reset_index(drop=True, inplace=True)

# %%
df1
# Out:
#      name age marks    Name
# 0    ramu  18    90    raju
# 1  aakash  21    65  aakash
# 2   raman  20    72   raman
# 3    raju  20    88  piyush

# %%
df1.loc[0]
# Out:
# name     ramu
# age        18
# marks      90
# Name     raju
# Name: 0, dtype: object

# %%
df1.loc[0,['age','marks']]
# Out:
# age      18
# marks    90
# Name: 0, dtype: object

# %%
df1.columns
# Out:
# Index(['name', 'age', 'marks', 'Name'], dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df1.set_index('name',inplace=True)

# %%
df1
# Out:
#        age marks    Name
# name
# ramu    18    90    raju
# aakash  21    65  aakash
# raman   20    72   raman
# raju    20    88  piyush

# %%
df1.loc['raju']
# Out:
# age          20
# marks        88
# Name     piyush
# Name: raju, dtype: object

# %%
df1.loc['raju','marks']
# Out:
# '88'

# %%
df1.loc['raju',['marks','Name']]
# Out:
# marks        88
# Name     piyush
# Name: raju, dtype: object

# %%
df1.iloc[0,1]
# Out:
# '90'

# %%
df1.iloc[0:,1:]
# Out:
#        marks    Name
# name
# ramu      90    raju
# aakash    65  aakash
# raman     72   raman
# raju      88  piyush

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
#      name age marks    Name
# 0    ramu  18    90    raju
# 1  aakash  21    65  aakash
# 2   raman  20    72   raman
# 3    raju  20    88  piyush

# %%
df1.sort_index()        #sorting index
# Out:
#      name age marks    Name
# 0    ramu  18    90    raju
# 1  aakash  21    65  aakash
# 2   raman  20    72   raman
# 3    raju  20    88  piyush

# %%
df1.sort_index(ascending=False)    #sorting in descending
# Out:
#      name age marks    Name
# 3    raju  20    88  piyush
# 2   raman  20    72   raman
# 1  aakash  21    65  aakash
# 0    ramu  18    90    raju

# %%
df1.sort_index(ascending=False,inplace=True)     #sorted inplace

# %%
df1
# Out:
#      name age marks    Name
# 3    raju  20    88  piyush
# 2   raman  20    72   raman
# 1  aakash  21    65  aakash
# 0    ramu  18    90    raju

# %%
df1.sort_index(inplace=True)

# %%
df1
# Out:
#      name age marks    Name
# 0    ramu  18    90    raju
# 1  aakash  21    65  aakash
# 2   raman  20    72   raman
# 3    raju  20    88  piyush

# %%
tf=df1['name']=='raju'

# %%
df1.loc[tf]
# Out:
#    name age marks    Name
# 3  raju  20    88  piyush

# %%
df1.loc[tf,'name']
# Out:
# 3    raju
# Name: name, dtype: object

# %%
df1.loc[tf,['name','marks']]
# Out:
#    name marks
# 3  raju    88

# %%
tf1=(df1['name']=='raju') & (df1['age']=='18')

# %%
df1.loc[tf1]
# Out:
# Empty DataFrame
# Columns: [name, age, marks, Name]
# Index: []

# %%
df1.loc[~tf1]
# Out:
#      name age marks    Name
# 0    ramu  18    90    raju
# 1  aakash  21    65  aakash
# 2   raman  20    72   raman
# 3    raju  20    88  piyush

# %%
df1.columns=['NAme','Marks','Age','neama']   #changing the columns name

# %%
df1
# Out:
#      NAme Marks Age   neama
# 0    ramu    18  90    raju
# 1  aakash    21  65  aakash
# 2   raman    20  72   raman
# 3    raju    20  88  piyush

# %%
df1['neama']='naam'

# %%
df1
# Out:
#      NAme Marks Age neama
# 0    ramu    18  90  naam
# 1  aakash    21  65  naam
# 2   raman    20  72  naam
# 3    raju    20  88  naam

# %%
df1.rename(columns={'neama': 'new_name'}, inplace=True)

# %%
df1
# Out:
#      NAme Marks Age new_name
# 0    ramu    18  90     naam
# 1  aakash    21  65     naam
# 2   raman    20  72     naam
# 3    raju    20  88     naam

# %%
df1.columns= [x.upper() for x in df1.columns]         #changing columns name to uppercase

# %%
df1
# Out:
#      NAME MARKS AGE NEW_NAME
# 0    ramu    18  90     naam
# 1  aakash    21  65     naam
# 2   raman    20  72     naam
# 3    raju    20  88     naam

# %%
df1['NAME']=[x.upper() for x in df1['NAME']]

# %%
df1
# Out:
#      NAME MARKS AGE NEW_NAME
# 0    RAMU    18  90     naam
# 1  AAKASH    21  65     naam
# 2   RAMAN    20  72     naam
# 3    RAJU    20  88     naam

# %%
df1.columns.str.replace('R','_')
# Out:
# Index(['NAME', 'MA_KS', 'AGE', 'NEW_NAME'], dtype='object')

# %%
df1.loc[2,['NAME','AGE']]=['RAhul','24']

# %%
df1
# Out:
#      NAME MARKS AGE NEW_NAME
# 0    RAMU    18  90     naam
# 1  AAKASH    21  65     naam
# 2   RAhul    20  24     naam
# 3    RAJU    20  88     naam

# %%
df1.drop('NEW_NAME', axis=1)    #not used inplace
# Out:
#      NAME MARKS AGE
# 0    RAMU    18  90
# 1  AAKASH    21  65
# 2   RAhul    20  24
# 3    RAJU    20  88

# %%
df1
# Out:
#      NAME MARKS AGE NEW_NAME
# 0    RAMU    18  90     naam
# 1  AAKASH    21  65     naam
# 2   RAhul    20  24     naam
# 3    RAJU    20  88     naam

# %%
df1.loc[4]=['chintu','80','20','chintua']     #adding row

# %%
df1
# Out:
#      NAME MARKS AGE NEW_NAME
# 0    RAMU    18  90     naam
# 1  AAKASH    21  65     naam
# 2   RAhul    20  24     naam
# 3    RAJU    20  88     naam
# 4  chintu    80  20  chintua

# %%
tf
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# Name: name, dtype: bool

# %%
tf1
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
df1['NEW_NAME'].str.lower()
# Out:
# 0       naam
# 1       naam
# 2       naam
# 3       naam
# 4    chintua
# Name: NEW_NAME, dtype: object

# %%
df1.at[2,'NEW_NAME']='ruhla'

# %%
df1
# Out:
#      NAME MARKS AGE NEW_NAME
# 0    RAMU    18  90     naam
# 1  AAKASH    21  65     naam
# 2   RAhul    20  24    ruhla
# 3    RAJU    20  88     naam
# 4  chintu    80  20  chintua

# %%
tf2=(df1['MARKS']=='21')

# %%
df1[tf2]
# Out:
#      NAME MARKS AGE NEW_NAME
# 1  AAKASH    21  65     naam

# %%
df1[tf2]['NAME']
# Out:
# 1    AAKASH
# Name: NAME, dtype: object

# %%
df1
# Out:
#      NAME MARKS AGE NEW_NAME
# 0    RAMU    18  90     naam
# 1  AAKASH    21  65     naam
# 2   RAhul    20  24    ruhla
# 3    RAJU    20  88     naam
# 4  chintu    80  20  chintua

# %%
df1.loc[tf2,['NAME']]='AAKU'

# %%
df1
# Out:
#      NAME MARKS AGE NEW_NAME
# 0    RAMU    18  90     naam
# 1    AAKU    21  65     naam
# 2   RAhul    20  24    ruhla
# 3    RAJU    20  88     naam
# 4  chintu    80  20  chintua

# %%
# apply map applymap replace

# %%
df1['NAME'].apply(len)       #apply function to only specefied column
# Out:
# 0    4
# 1    4
# 2    5
# 3    4
# 4    6
# Name: NAME, dtype: int64

# %%
df1['MARKS'].apply(len)
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: MARKS, dtype: int64

# %%
def update_name(NAME):
  return NAME.lower()

#using function

# %%
df1['NAME'].apply(update_name)
# Out:
# 0      ramu
# 1      aaku
# 2     rahul
# 3      raju
# 4    chintu
# Name: NAME, dtype: object

# %%
def update_naam(name):
  return name.upper()

# %%
df1['NAME'].apply(update_naam)
# Out:
# 0      RAMU
# 1      AAKU
# 2     RAHUL
# 3      RAJU
# 4    CHINTU
# Name: NAME, dtype: object

# %%
df1
# Out:
#      NAME MARKS AGE NEW_NAME
# 0    RAMU    18  90     naam
# 1    AAKU    21  65     naam
# 2   RAhul    20  24    ruhla
# 3    RAJU    20  88     naam
# 4  chintu    80  20  chintua

# %%
df1['NAME']=df1['NAME'].apply(lambda x:x.lower())
#lambda keyword similar to user defined function

# %%
df1
# Out:
#      NAME MARKS AGE NEW_NAME
# 0    ramu    18  90     naam
# 1    aaku    21  65     naam
# 2   rahul    20  24    ruhla
# 3    raju    20  88     naam
# 4  chintu    80  20  chintua

# %%
df1.apply(len)
# Out:
# NAME        5
# MARKS       5
# AGE         5
# NEW_NAME    5
# dtype: int64

# %%
len(df1['NAME'])
# Out:
# 5

# %%
df1.apply(len,axis='rows')
# Out:
# NAME        5
# MARKS       5
# AGE         5
# NEW_NAME    5
# dtype: int64

# %%
df1.apply(len,axis='columns')
# Out:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4
# dtype: int64

# %%
df1.apply(pd.Series.min)    #will return you the minimun series which is there in Dataframe
# Out:
# NAME           aaku
# MARKS            18
# AGE              20
# NEW_NAME    chintua
# dtype: object

# %%
df1
# Out:
#      NAME MARKS AGE NEW_NAME
# 0    ramu    18  90     naam
# 1    aaku    21  65     naam
# 2   rahul    20  24    ruhla
# 3    raju    20  88     naam
# 4  chintu    80  20  chintua

# %%
df1.apply(lambda y:y.min())
# Out:
# NAME           aaku
# MARKS            18
# AGE              20
# NEW_NAME    chintua
# dtype: object

# %%
df1.applymap(len)      #applymap applies to whole address
# Out:
#    NAME  MARKS  AGE  NEW_NAME
# 0     4      2    2         4
# 1     4      2    2         4
# 2     5      2    2         5
# 3     4      2    2         4
# 4     6      2    2         7

# %%
df1.apply(len)
# Out:
# NAME        5
# MARKS       5
# AGE         5
# NEW_NAME    5
# dtype: int64

# %%
df1=df1.applymap(str.lower)

# %%
df1
# Out:
#      NAME MARKS AGE NEW_NAME
# 0    ramu    18  90     naam
# 1    aaku    21  65     naam
# 2   rahul    20  24    ruhla
# 3    raju    20  88     naam
# 4  chintu    80  20  chintua

# %%
df1['NAME'].map({'ramu':'raj','chintu':'rohit'})
# Out:
# 0      raj
# 1      NaN
# 2      NaN
# 3      NaN
# 4    rohit
# Name: NAME, dtype: object

# %%
df1
# Out:
#      NAME MARKS AGE NEW_NAME
# 0    ramu    18  90     naam
# 1    aaku    21  65     naam
# 2   rahul    20  24    ruhla
# 3    raju    20  88     naam
# 4  chintu    80  20  chintua

# %%
df1['NAME'].replace({'ramu':'raj','chintu':'rohit'})
# Out:
# 0      raj
# 1     aaku
# 2    rahul
# 3     raju
# 4    rohit
# Name: NAME, dtype: object

# %%
df1['NAME']=df1['NAME'].replace({'ramu':'raj','chintu':'rohit'})

# %%
df1
# Out:
#     NAME MARKS AGE NEW_NAME
# 0    raj    18  90     naam
# 1   aaku    21  65     naam
# 2  rahul    20  24    ruhla
# 3   raju    20  88     naam
# 4  rohit    80  20  chintua

# %%
df1.rename(columns={'AGE':'umrr'})  #cn use inplace
# Out:
#     NAME MARKS umrr NEW_NAME
# 0    raj    18   90     naam
# 1   aaku    21   65     naam
# 2  rahul    20   24    ruhla
# 3   raju    20   88     naam
# 4  rohit    80   20  chintua

# %%
df1.rename(columns={'AGE':'umrr'},inplace=True)

# %%
df1['umrr']
# Out:
# 0    90
# 1    65
# 2    24
# 3    88
# 4    20
# Name: umrr, dtype: object

# %%
df2=pd.read_csv('titanic.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-107-27fc56a98a9c> in <cell line: 1>()
# ----> 1 df2=pd.read_csv('titanic.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df2

# %%
df2['Survived'].map({1:'true',0:'false'})

# %%
df2['Survived']=df2['Survived'].map({1:'true',0:'false'})

# %%
df2

# %%
# Add and remove rows/column

# %%
df1

# %%
df1['NAME']+' ,'+df1['NEW_NAME']

# %%
df1['new']=df1['NAME']+' '+df1['NEW_NAME']

# %%
df1

# %%
df1.drop(columns=['NAME'])    #can use inplace

# %%
df1['new'].str.split(' ',expand=True)   #splitting the column

# %%
df1

# %%
df1[['pelha','dusra']]=df1['new'].str.split(' ',expand=True)

# %%
df1

# %%
df1.append({'NAME':'chomu'},ignore_index=True)    #adding new name

# %%
students= { 'name':['rakesh','pataal'],
          'age':['18','15'],
           'marks':['72','88']}

# %%
df3=pd.DataFrame(students)

# %%
df3

# %%
df1.append(df3)           #concatenating two dataframe

# %%
df1

# %%
df1=df1.append(df3,sort=False)

# %%
df1

# %%
df1=df1.append(df3,sort=False,ignore_index=True)

# %%
df1

# %%
df1.drop(index=8)

# %%
df1.drop(index=df1[df1['age']=='18'].index)

# %%
#sorting

# %%
df1.sort_values('MARKS',ascending=False)

# %%
df1.sort_values(['MARKS','NAME'],ascending=False)

# %%
df1.sort_values(['MARKS','NAME'],ascending=[False,True])

# %%
df1.sort_index()

# %%
df1.sort_values(by='MARKS',ascending=False)

# %%
df1['NAME'].head(7)

# %%
df1[['NAME','umrr']].head(7)
